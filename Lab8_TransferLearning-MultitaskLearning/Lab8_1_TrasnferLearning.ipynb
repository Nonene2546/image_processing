# %% [markdown]
# # **Lab 8.1 Transfer Learning & Multitask Learning**

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision.models as models
import torchvision.transforms as transforms

from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader,Subset,Dataset,random_split
from PIL import Image


import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import os
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# Complete the `MultiLanguageHandwrittenDataset` class below. It should return:
# - `image`: the image data
# - `label`: the digit label (0-9)
# - `language`: the language (Thai or English)

# %%
### START CODE HERE ###
class MultiLanguageHandwrittenDataset(Dataset):
    def __init__(self, root_dirs, languages, transforms=None):
        self.root_dirs = root_dirs
        self.languages = languages
        self.transform = transforms
        self.samples = []
        for root_dir, language in zip(self.root_dirs, self.languages):
            for subdir in os.scandir(root_dir):
                if subdir.is_dir():
                    label = int(subdir.name)
                    for file in os.scandir(subdir.path):
                        if file.is_file():
                            self.samples.append((file.path, label, language))
        print(self.samples)

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        path, label, language = self.samples[idx]
        image = plt.imread(path)
        image = self.transform(image)
        return image, label, language
### END CODE HERE ###

# %% [markdown]
# use you `MultiLanguageHandwrittenDataset` here and display the first batch
# <details>
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical
#
# ![image.png](https://github.com/Digital-Image-Processing-Laboratory/image_processing-2024/blob/master/Lab8_TransferLearning-MultitaskLearning/assets/1.png?raw=true)
#
# </details>

# %%
### START CODE HERE ###
from torchvision.models import MobileNet_V3_Small_Weights

root_dirs = ['/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset',
             '/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/thai-handwritten-dataset']
languages = ['eng', 'thai']

def reverse_if_white(image):
    copy_image = np.array(image.copy())
    h, w, c = copy_image.shape

    if np.max(copy_image) > 1:
        copy_image = copy_image/255
        
    if np.sum(copy_image) > h*w*c/2:
        copy_image = 1 - copy_image
        
    return copy_image

transform = transforms.Compose([
    reverse_if_white,
    transforms.ToTensor(),
    MobileNet_V3_Small_Weights.IMAGENET1K_V1.transforms()
])

dataset = MultiLanguageHandwrittenDataset(root_dirs, languages, transform)
dataloader = DataLoader(dataset, batch_size=16, shuffle=True)
### END CODE HERE ###
# Out:
# [('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_582.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_1460.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_824.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_1658.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_654.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_1717.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_1315.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_1088.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_206.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_1239.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_254.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_237.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_1269.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_1749.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_931.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_938.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_464.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_608.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_1129.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_1338.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_816.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_786.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_966.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_1043.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_304.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_872.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/data/data/eng-handwritten-dataset/7/img_738.jpg', 7, 'eng'), ('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-Multita ...

# %%
features, labels, languages = next(iter(dataloader))

fig, axs = plt.subplots(4, 4, figsize=(10, 10))
for i, ax in enumerate(axs.flatten()):
    ax.imshow(features[i].permute(1, 2, 0))
    ax.set_title(f'{labels[i].item()}_{languages[i]}')
    ax.axis('off')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Transfer learning

# %% [markdown]
# Complete the `customVGG16` class below, which can create a pretrained VGG16 model and customize the number of fully connected (FC) layers. It also allows adding new convolutional layers and unfreezing pretrained layers based on their index.

# %%
### START CODE HERE ###
class customModel(nn.Module):
    def __init__(self, add_feat_dims=None, h_dims=None, num_classes=10, input_size=(1,28,28), trainable_layers_idx=None):
        super(customModel, self).__init__()
        self.model = models.mobilenet_v3_small(weights=MobileNet_V3_Small_Weights.IMAGENET1K_V1)
        for param in self.model.features[:].parameters():
            param.requires_grad = False

        for param in self.model.classifier.parameters():
            param.requires_grad = True
        if trainable_layers_idx is not None:
            for idx in trainable_layers_idx:
                for param in self.model.features[idx].parameters():
                    param.requires_grad = True
        
        channels = [576]
        if add_feat_dims is not None:
            channels.extend(add_feat_dims)
            for i in range(1, len(add_feat_dims) + 1):
                self.model.features.add_module(f'added_layer_{i}', nn.Conv2d(channels[i - 1], channels[i], kernel_size=3, padding='same'))
        
        hchannels = [channels[-1]]
        if h_dims is not None:
            layers = []
            hchannels.extend(h_dims)
            for i in range(1, len(h_dims) + 1):
                layers.append(nn.Linear(hchannels[i - 1], hchannels[i]))
                layers.append(nn.Dropout(0.4, inplace=False))
                layers.append(nn.ReLU())
            self.model.classifier = nn.Sequential(*layers, nn.Linear(hchannels[-1], num_classes))
        else:
            self.model.classifier[-1] = nn.Linear(1024, num_classes)
            self.model.classifier[0] = nn.Linear(channels[-1], 1024)


    def _get_input_size_fc(self, input_shape):
        with torch.no_grad():
            x = torch.zeros(1, *input_shape)
            x = self.model.features(x)
            x = self.model.avgpool(x)
            x = torch.flatten(x[0])
            return x.size(0)
    
    def forward(self, x):
        x = self.model(x)
        return x
### END CODE HERE ###

# %%
from torchsummary import summary
model = customModel([123], [12, 12, 1])
summary(model, (3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 112, 112]             432
#        BatchNorm2d-2         [-1, 16, 112, 112]              32
#          Hardswish-3         [-1, 16, 112, 112]               0
#             Conv2d-4           [-1, 16, 56, 56]             144
#        BatchNorm2d-5           [-1, 16, 56, 56]              32
#               ReLU-6           [-1, 16, 56, 56]               0
#  AdaptiveAvgPool2d-7             [-1, 16, 1, 1]               0
#             Conv2d-8              [-1, 8, 1, 1]             136
#               ReLU-9              [-1, 8, 1, 1]               0
#            Conv2d-10             [-1, 16, 1, 1]             144
#       Hardsigmoid-11             [-1, 16, 1, 1]               0
# SqueezeExcitation-12           [-1, 16, 56, 56]               0
#            Conv2d-13           [-1, 16, 56, 56]             256
#       BatchNorm2d-14           [-1, 16, 56, 56]              32
#  InvertedResidual-15           [-1, 16, 56, 56]               0
#            Conv2d-16           [-1, 72, 56, 56]           1,152
#       BatchNorm2d-17           [-1, 72, 56, 56]             144
#              ReLU-18           [-1, 72, 56, 56]               0
#            Conv2d-19           [-1, 72, 28, 28]             648
#       BatchNorm2d-20           [-1, 72, 28, 28]             144
#              ReLU-21           [-1, 72, 28, 28]               0
#            Conv2d-22           [-1, 24, 28, 28]           1,728
#       BatchNorm2d-23           [-1, 24, 28, 28]              48
#  InvertedResidual-24           [-1, 24, 28, 28]               0
#            Conv2d-25           [-1, 88, 28, 28]           2,112
#       BatchNorm2d-26           [-1, 88, 28, 28]             176
#              ReLU-27           [-1, 88, 28, 28]               0
#            Conv2d-28           [-1, 88, 28, 28]             792
#       BatchNorm2d-29           [-1, 88, 28, 28]             176
#              ReLU-30           [-1, 88, 28, 28]               0
#            Conv2d-31           [-1, 24, 28, 28]           2,112
#       BatchNorm2d-32           [-1, 24, 28, 28]              48
#  InvertedResidual-33           [-1, 24, 28, 28]               0
#            Conv2d-34           [-1, 96, 28, 28]           2,304
#       BatchNorm2d-35           [-1, 96, 28, 28]             192
#         Hardswish-36           [-1, 96, 28, 28]               0
#            Conv2d-37           [-1, 96, 14, 14]           2,400
#       BatchNorm2d-38           [-1, 96, 14, 14]             192
#         Hardswish-39           [-1, 96, 14, 14]               0
# AdaptiveAvgPool2d-40             [-1, 96, 1, 1]               0
#            Conv2d-41             [-1, 24, 1, 1]           2,328
#              ReLU-42             [-1, 24, 1, 1]               0
#            Conv2d-43             [-1, 96, 1, 1]           2,400
#       Hardsigmoid-44             [-1, 96, 1, 1]               0
# SqueezeExcitation-45           [-1, 96, 14, 14]               0
#            Conv2d-46           [-1, 40, 14, 14]           3,840
#       BatchNorm2d-47           [-1, 40, 14, 14]              80
#  InvertedResidual-48           [-1, 40, 14, 14]               0
#            Conv2d-49          [-1, 240, 14, 14]           9,600
#       BatchNorm2d-50          [-1, 240, 14, 14]             480
#         Hardswish-51          [-1, 240, 14, 14]               0
#            Conv2d-52          [-1, 240, 14, 14]           6,000
#       BatchNorm2d-53          [-1, 240, 14, 14]             480
#         Hardswish-54          [-1, 240, 14, 14]               0
# AdaptiveAvgPool2d-55            [-1, 240, 1, 1]               0
#            Conv2d-56             [-1, 64, 1, 1]          15,424
#              ReLU-57             [-1, 64, 1, 1]               0
#            Conv2d-58            [-1, 240, 1, 1]          15,600
#       Hardsigmoid-59            [-1, 240, 1, 1]               0
# SqueezeExcitation-60          [-1, 240, 14, 14]               0
#            Conv2d-61           [-1, 40, 14, 14]           9,600
#       BatchNorm2d-62           [-1, 40, 14, 14]              80
#  InvertedResidual-63           [-1, 40, 14, 14]               0
#            Conv2d-64          [-1, 240, 14, 14]           9,600
#       BatchNorm2d-65          [-1, 240, 14, 14]             480
#         Hardswish-66          [-1, 240, 14, 14]               0
#            Conv2d-67          [-1, 240, 14, 14]           6,000
#       BatchNorm2d-68          [-1, 240, 14, 14]             480
#         Hardswish-69          [-1, 240, 14, 14]               0
# AdaptiveAvgPool2d-70            [-1, 240, 1, 1]               0
#            Conv2d-71             [-1, 64, 1, 1]          15,424
#              ReLU-72             [-1, 64, 1, 1]               0
#            Conv2d-73            [-1, 240, 1, 1]          15,600
#       Hardsigmoid-74            [-1, 240, 1, 1]               0
# SqueezeExcitation-75          [-1, 240, 14, 14]               0
#            Conv2d-76           [-1, 40, 14, 14]           9,600
#       BatchNorm2d-77           [-1, 40, 14, 14]              80
#  InvertedResidual-78           [-1, 40, 14, 14]               0
#            Conv2d-79          [-1, 120, 14, 14]           4,800
#       BatchNorm2d-80          [-1, 120, 14, 14]             240
#         Hardswish-81          [-1, 120, 14, 14]               0
#            Conv2d-82          [-1, 120, 14, 14]           3,000
#       BatchNorm2d-83          [-1, 120, 14, 14]             240
#         Hardswish-84          [-1, 120, 14, 14]               0
# AdaptiveAvgPool2d-85            [-1, 120, 1, 1]               0
#            Conv2d-86             [-1, 32, 1, 1]           3,872
#              ReLU-87             [-1, 32, 1, 1]               0
#            Conv2d-88            [-1, 120, 1, 1]           3,960
#       Hardsigmoid-89            [-1, 120, 1, 1]               0
# SqueezeExcitation-90          [-1, 120, 14, 14]               0
#            Conv2d-91           [-1, 48, 14, 14]           5,760
#       BatchNorm2d-92           [-1, 48, 14, 14]              96
#  InvertedResidual-93           [-1, 48, 14, 14]               0
#            Conv2d-94          [-1, 144, 14, 14]           6,912
#       BatchNorm2d-95          [-1, 144, 14, 14]             288
#         Hardswish-96          [-1, 144, 14, 14]               0
#            Conv2d-97          [-1, 144, 14, 14]           3,600
#       BatchNorm2d-98          [-1, 144, 14, 14]             288
#         Hardswish-99          [-1, 144, 14, 14]               0
# AdaptiveAvgPool2d-100            [-1, 144, 1, 1]               0
#           Conv2d-101             [-1, 40, 1, 1]           5,800
#             ReLU-102             [-1, 40, 1, 1]               0
#           Conv2d-103            [-1, 144, 1, 1]           5,904
#      Hardsigmoid-104            [-1, 144, 1, 1]               0
# SqueezeExcitation-105          [-1, 144, 14, 14]               0
#           Conv2d-106           [-1, 48, 14, 14]           6,912
#      BatchNorm2d-107           [-1, 48, 14, 14]              96
# InvertedResidual-108           [-1, 48, 14, 14]               0
#           Conv2d-109          [-1, 288, 14, 14]          13,824
#      BatchNorm2d-110          [-1, 288, 14, 14]             576
#        Hardswish-111          [-1, 288, 14, 14]               0
#           Conv2d-112            [-1, 288, 7, 7]           7,200
#      BatchNorm2d-113            [-1, 288, 7, 7]             576
#        Hardswish-114            [-1, 288, 7, 7]               0
# AdaptiveAvgPool2d-115            [-1, 288, 1, 1]               0
#           Conv2d-116             [-1, 72, 1, 1]          20,808
#             ReLU-117             [-1, 72, 1, 1]               0
#           Conv2d-118            [-1, 288, 1, 1]          21,024
#      Hardsigmoid-119            [-1, 288, 1, 1]               0
# SqueezeExcitation-120            [-1, 288, 7, 7]               0
#           Conv2d-121             [-1, 96, 7, 7]          27,648
#      BatchNorm2d-122             [-1, 96, 7, 7]             192
# InvertedResidual-123             [-1, 96, 7, 7]               0
#           Conv2d-124            [-1, 576, 7, 7]          55,296
#      BatchNorm2d-125            [-1, 576, 7, 7]           1,152
#        Hardswish-126            [-1, 576, 7, 7]               0
#           Conv2d-127            [-1, 576, 7, 7]          14,400
#      BatchNorm2d-128            [-1, 576, 7, 7]           1,152
#        Hardswish-129            [-1, 576, 7, 7]               0
# AdaptiveAvgPool2d-130            [-1, 576, 1, 1]               0
#           Conv2d-131            [-1, 144, 1, 1]          83,088
#             ReLU-132            [-1, 144, 1, 1]               0
#           Conv2d-133            [-1, 576, 1, 1]          83,520
#      Hardsigmoid-134            [-1, 576, 1, 1]               0
# SqueezeExcitation-135            [-1, 576, 7, 7]               0
#           Conv2d-136             [-1, 96, 7, 7]          55,296
#      BatchNorm2d-137             [-1, 96, 7, 7]             192
# InvertedResidual-138             [-1, 96, 7, 7]               0
#           Conv2d-139            [-1, 576, 7, 7]          55,296
#      BatchNorm2d-140            [-1, 576, 7, 7]           1,152
#        Hardswish-141            [-1, 576, 7, 7]               0
#           Conv2d-142            [-1, 576, 7, 7]          14,400
#      BatchNorm2d-143            [-1, 576, 7, 7]           1,152
#        Hardswish-144            [-1, 576, 7, 7]               0
# AdaptiveAvgPool2d-145            [-1, 576, 1, 1]               0
#           Conv2d-146            [-1, 144, 1, 1]          83,088
#             ReLU-147            [-1, 144, 1, 1]               0
#           Conv2d-148            [-1, 576, 1, 1]          83,520
#      Hardsigmoid-149            [-1, 576, 1, 1]               0
# SqueezeExcitation-150            [-1, 576, 7, 7]               0
#           Conv2d-151             [-1, 96, 7, 7]          55,296
#      BatchNorm2d-152             [-1, 96, 7, 7]             192
# InvertedResidual-153             [-1, 96, 7, 7]               0
#           Conv2d-154            [-1, 576, 7, 7]          55,296
#      BatchNorm2d-155            [-1, 576, 7, 7]           1,152
#        Hardswish-156            [-1, 576, 7, 7]               0
#           Conv2d-157            [-1, 123, 7, 7]         637,755
# AdaptiveAvgPool2d-158            [-1, 123, 1, 1]               0
#           Linear-159                   [-1, 12]           1,488
#          Dropout-160                   [-1, 12]               0
#             ReLU-161                   [-1, 12]               0
#           Linear-162                   [-1, 12]             156
#          Dropout-163                   [-1, 12]               0
#             ReLU-164                   [-1, 12]               0
#           Linear-165                    [-1, 1]              13
#          Dropout-166                    [-1, 1]               0
#             ReLU-167                    [-1, 1]               0
#           Linear-168                   [-1, 10]              20
#      MobileNetV3-169                   [-1, 10]               0
# ================================================================
# Total params: 1,566,440
# Trainable params: 639,432
# Non-trainable params: 927,008
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 34.62
# Params size (MB): 5.98
# Estimated Total Size (MB): 41.17
# ----------------------------------------------------------------

# %% [markdown]
# Example usage
# ```
# trainable_layers_idx = [-1,-2,-3,-4,-5]
# model = customVGG16(add_feat_dims=[512],h_dims=[512,256,256],input_size=(3,224,224),trainable_layers_idx=trainable_layers_idx)
#
# ```

# %% [markdown]
# Complete the `train` function below, which logs Loss/train, Accuracy/train, Loss/test, and Accuracy/test to [TensorBoard](https://pytorch.org/docs/stable/tensorboard.html).Then, complete the evaluate_task function, which prints the classification report and plots the confusion matrix

# %%
### START CODE HERE ###
import os
def train(model,opt,loss_fn,train_loader,val_loader,epochs=10,writer=None,checkpoint_path=None,device='cpu',task='digit'):



def evaluate_task(y_true, y_pred, task_name="Task"):
    pass
### END CODE HERE ###

# %% [markdown]
# ### Transfer learning for Digit classification task
# Declare the `customVGG16` model with custom layers of your choice. Then, split the dataset into training, validation, and test sets, and proceed to train the model.

# %%
### START CODE HERE ###
from torch.utils.tensorboard import SummaryWriter

model1 = customModel()

train_dataset, val_dataset, test_dataset = random_split(dataset, [0.8, 0.1, 0.1])

writer = SummaryWriter('/home/crueang/Chaks/image_processing-2024/Lab8_TransferLearning-MultitaskLearning/outputs/tensorboard')
optimizer = torch.optim.Adam(model1.parameters(), lr=0.001)
loss_fn = nn.CrossEntropyLoss()
### END CODE HERE ###
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 11
#       9 optimizer = torch.optim.Adam(model1.parameters(), lr=0.001)
#      10 loss_fn = nn.CrossEntropyLoss()
# ---> 11 train(None)
#
# TypeError: train() missing 4 required positional arguments: 'opt', 'loss_fn', 'train_loader', and 'val_loader'

# %% [markdown]
# use `evaluate_task` to evlauate you model1 here.
# <details>
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical
#
# ```
# Digit - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84        26
#            1       0.75      0.94      0.83        32
#            2       0.66      0.54      0.59        39
#            3       0.76      0.54      0.63        35
#            4       0.68      0.53      0.60        47
#            5       0.52      0.42      0.47        33
#            6       0.59      0.88      0.71        33
#            7       0.46      0.59      0.52        27
#            8       0.70      0.65      0.67        43
#            9       0.85      0.83      0.84        35
#
#     accuracy                           0.67       350
#    macro avg       0.67      0.68      0.67       350
# weighted avg       0.68      0.67      0.67       350
#
# ```
#
# ![image.png](https://github.com/Digital-Image-Processing-Laboratory/image_processing-2024/blob/master/Lab8_TransferLearning-MultitaskLearning/assets/2.png?raw=true)
#
# </details>

# %%
### START CODE HERE ###

### END CODE HERE ###

# %% [markdown]
# ### Transfer learning for Language classification task
# Declare a NEW `customVGG16` model with custom layers of your choice.

# %%
### START CODE HERE ###
model2 = customVGG16(None)

train_dataset, val_dataset, test_dataset = None

writer = None
opt = None
loss_fn = None
train(None)
### END CODE HERE ###

# %% [markdown]
# use `evaluate_task` to evlauate you model2 here.
# <details>
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical
#
# ```
# Language - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96       175
#            1       0.99      0.93      0.96       175
#
#     accuracy                           0.96       350
#    macro avg       0.96      0.96      0.96       350
# weighted avg       0.96      0.96      0.96       350
#
# ```
#
# ![image.png](https://github.com/Digital-Image-Processing-Laboratory/image_processing-2024/blob/master/Lab8_TransferLearning-MultitaskLearning/assets/3.png?raw=true)
#
# </details>

# %%
### START CODE HERE ###

### END CODE HERE ###

# %% [markdown]
# ---

# %% [markdown]
# ## Multitask learning

# %% [markdown]
# Complete the `customVGG16_multitask` class below, which can create a pretrained VGG16 model and customize the number of fully connected (FC) layers. It also allows adding new convolutional layers and unfreezing pretrained layers based on their index. Additionally, it allows branching the model into two heads for multitask learning, where one head handles digit classification, and the other handles language classification

# %%
class CustomModel_Multitask(nn.Module):
    def __init__(self,add_feat_dims=None,h_dims=None,input_size=(1,28,28),trainable_layers_idx=None):
        super(CustomModel_Multitask, self).__init__()
        self.model = models.mobilenet_v3_small(weights=MobileNet_V3_Small_Weights.IMAGENET1K_V1)
        for param in self.model.features[:].parameters():
            param.requires_grad = False

        for param in self.model.classifier.parameters():
            param.requires_grad = True
        if trainable_layers_idx is not None:
            for idx in trainable_layers_idx:
                for param in self.model.features[idx].parameters():
                    param.requires_grad = True
        
        channels = [576]
        if add_feat_dims is not None:
            channels.extend(add_feat_dims)
            for i in range(1, len(add_feat_dims) + 1):
                self.model.features.add_module(f'added_layer_{i}', nn.Conv2d(channels[i - 1], channels[i], kernel_size=3, padding='same'))
        
        hchannels = [channels[-1]]
        if h_dims is not None:
            layers = []
            hchannels.extend(h_dims)
            for i in range(1, len(h_dims) + 1):
                layers.append(nn.Linear(hchannels[i - 1], hchannels[i]))
                layers.append(nn.Dropout(0.4, inplace=False))
                layers.append(nn.ReLU())
            self.model.classifier = nn.Sequential(*layers, nn.Linear(hchannels[-1], 10))
        else:
            self.model.classifier[-1] = nn.Linear(1024, 10)
            self.model.classifier[0] = nn.Linear(channels[-1], 1024)
        
        self.digit = self.model.classifier
        self.lang = self.model.classifier
        self.lang[-1] = nn.Linear(1024, 2)

    def _get_input_size_fc(self, input_shape):
        with torch.no_grad():
            x = torch.zeros(1, *input_shape)
            x = self.model.features(x)
            x = self.model.avgpool(x)
            x = torch.flatten(x[0])
            return x.size(0)
    
    def forward(self, x):

        out1 = self.digit(x)
        out2 = self.lang(x)

        return out1,out2

# %%
model_multi = CustomModel_Multitask()
summary(model_multi, (3, 224, 224))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model_multi = CustomModel_Multitask()
#       2 summary(model_multi, (3, 224, 224))
#
# NameError: name 'CustomModel_Multitask' is not defined

# %% [markdown]
# Complete the `train_multi` function below, which train multitask model and  logs Loss/train, Accuracy/train, Loss/test, and Accuracy/test to [TensorBoard](https://pytorch.org/docs/stable/tensorboard.html).

# %%
def train_multi(model, opt, loss_fn, train_loader, val_loader, epochs=10, writer=None, checkpoint_path=None, device='cpu'):
    pass

# %%
### START CODE HERE ###
model = customVGG16(None)

train_dataset, val_dataset, test_dataset = None

writer = None
opt = None
loss_fn = None
train(None)
### END CODE HERE ###

# %% [markdown]
# use `evaluate_task` to evlauate you model here.
# <details>
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical
#
# ```
# Digit - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86        35
#            1       0.81      0.91      0.85        32
#            2       0.76      0.55      0.64        40
#            3       0.53      0.66      0.58        32
#            4       0.54      0.29      0.38        24
#            5       0.51      0.57      0.54        37
#            6       0.68      0.72      0.70        29
#            7       0.60      0.71      0.65        34
#            8       0.62      0.71      0.66        48
#            9       0.68      0.49      0.57        39
#
#     accuracy                           0.65       350
#    macro avg       0.66      0.65      0.64       350
# weighted avg       0.66      0.65      0.65       350
#
# ```
#
# ![image.png](https://github.com/Digital-Image-Processing-Laboratory/image_processing-2024/blob/master/Lab8_TransferLearning-MultitaskLearning/assets/4.png?raw=true)
#
# ```
# Language - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       172
#            1       0.98      0.98      0.98       178
#
#     accuracy                           0.98       350
#    macro avg       0.98      0.98      0.98       350
# weighted avg       0.98      0.98      0.98       350
# ```
#
# ![image-2.png](https://github.com/Digital-Image-Processing-Laboratory/image_processing-2024/blob/master/Lab8_TransferLearning-MultitaskLearning/assets/5.png?raw=true)
#
# </details>

# %%
### START CODE HERE ###

### END CODE HERE ###

# %% [markdown]
# ---
# # Question
# 1. If you build two separate models, one for each task with a different classification problem,
# how does the overall model size of two separate models compared to a single model with shared layers and two classifiers
# at the end?
#
# 2. In what scenarios might a single model with two classifiers outperform two separate models in terms of generalization? Is there a risk of one task negatively affecting the other?
#
# 3. How can weighted loss functions be applied in a single model with two classifiers to balance the performance of both tasks?
